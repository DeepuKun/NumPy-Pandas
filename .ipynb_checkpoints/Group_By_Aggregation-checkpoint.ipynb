# %%
import pandas as pd

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S1', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}
df=pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S1    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#Group By Categories and calculate sum of sales 
obj = df.groupby("Category")
for i in obj:
    print(i)
# Out:
# ('A',   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07)
# ('B',   Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S1    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08)

# %%
obj = df.groupby("Category")['Sales'].sum()
for i in obj:
    print(i)
# Out:
# 570
# 930

# %%
obj = df.groupby(["Category", "Store"])['Sales'].sum()

# %%
obj
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       680
#           S2       250
# Name: Sales, dtype: int64

# %%
df["Sales"].mean() #Similarly Meadian, Mode, Min, Max, Count, std (Std deviation)
# Out:
# np.float64(187.5)

# %%
df["Sales"].agg(['mean','median','min','max','sum','count'])
# Out:
# mean       187.5
# median     190.0
# min        100.0
# max        300.0
# sum       1500.0
# count        8.0
# Name: Sales, dtype: float64
