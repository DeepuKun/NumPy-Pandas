# %%
import pandas as pd
import numpy as np

data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': [
        'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South',
        'East', 'West', 'North', 'South'
    ],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': [
        'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice',
        'John', 'Mary', 'Bob', 'Alice'
    ]
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    536     79   John  January      Q1
# 1  2023-01-02       B   West    621     89   Mary  January      Q1
# 2  2023-01-03       C  North    104     66    Bob  January      Q1
# 3  2023-01-04       D  South    776     46  Alice  January      Q1
# 4  2023-01-05       A   East    572     90   John  January      Q1
# 5  2023-01-06       B   West    247     35   Mary  January      Q1
# 6  2023-01-07       C  North    367     72    Bob  January      Q1
# 7  2023-01-08       D  South    949     67  Alice  January      Q1
# 8  2023-01-09       A   East    815     15   John  January      Q1
# 9  2023-01-10       B   West    846     47   Mary  January      Q1
# 10 2023-01-11       C  North    200     80    Bob  January      Q1
# 11 2023-01-12       D  South    986     47  Alice  January      Q1
# 12 2023-01-13       A   East    373     46   John  January      Q1
# ...

# %%
pd.pivot_table(df,values= 'Sales', index ="Region", columns ="Product" , aggfunc = "median")
# Out:
# Product      A      B      C      D
# Region
# East     572.0    NaN    NaN    NaN
# North      NaN    NaN  367.0    NaN
# South      NaN    NaN    NaN  776.0
# West       NaN  462.0    NaN    NaN

# %%
pd.pivot_table(df,values= 'Sales', index ="Region", columns ="Product") #mean by default
# Out:
# Product      A      B      C      D
# Region
# East     583.2    NaN    NaN    NaN
# North      NaN    NaN  433.4    NaN
# South      NaN    NaN    NaN  698.4
# West       NaN  527.4    NaN    NaN

# %%
pd.crosstab(df["Region"], df["Product"]) #crosstab is used for counting, pivot_table is used for agg functions
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
