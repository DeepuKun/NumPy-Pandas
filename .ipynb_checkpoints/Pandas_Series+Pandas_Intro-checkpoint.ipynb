# %%
import numpy as np
import pandas as pd

# %%
labels = ['A', 'B','C']
my_list = [10, 20, 30]
arr = np.array([1,2,3])
d = {1:20, 3 :20, 2:30}

# %%
s = pd.Series(my_list, index = labels)

# %%
print(s)
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
pd.Series(arr, index = labels)
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    20
# 3    20
# 2    30
# dtype: int64

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda', 'David', 'Sophia'],
    'Age': [28, 34, 29, 42, 25, 31],
    'City': ['New York', 'Paris', 'Berlin', 'London', 'Tokyo', 'Sydney'],
    'Salary': [65000, 70000, 62000, 85000, 55000, 78000]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2   Peter   29    Berlin   62000
# 3   Linda   42    London   85000
# 4   David   25     Tokyo   55000
# 5  Sophia   31    Sydney   78000

# %%
df["Name"]
# Out:
# 0      John
# 1      Anna
# 2     Peter
# 3     Linda
# 4     David
# 5    Sophia
# Name: Name, dtype: object

# %%
df[["Name", "Age"]]
# Out:
#      Name  Age
# 0    John   28
# 1    Anna   34
# 2   Peter   29
# 3   Linda   42
# 4   David   25
# 5  Sophia   31

# %%
df["Designation"] =["Engineer","Doctor","Engineer","Doctor","Engineer","Doctor"] #Add a new Coloum

# %%
df
# Out:
#      Name  Age      City  Salary Designation
# 0    John   28  New York   65000    Engineer
# 1    Anna   34     Paris   70000      Doctor
# 2   Peter   29    Berlin   62000    Engineer
# 3   Linda   42    London   85000      Doctor
# 4   David   25     Tokyo   55000    Engineer
# 5  Sophia   31    Sydney   78000      Doctor

# %%
df.drop("Designation", axis = 1) # By Default axis = 0, row wise ->
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2   Peter   29    Berlin   62000
# 3   Linda   42    London   85000
# 4   David   25     Tokyo   55000
# 5  Sophia   31    Sydney   78000

# %%
df #only temp/ for view deletion, no removal from main data.
# Out:
#      Name  Age      City  Salary Designation
# 0    John   28  New York   65000    Engineer
# 1    Anna   34     Paris   70000      Doctor
# 2   Peter   29    Berlin   62000    Engineer
# 3   Linda   42    London   85000      Doctor
# 4   David   25     Tokyo   55000    Engineer
# 5  Sophia   31    Sydney   78000      Doctor

# %%
df.drop('Designation', axis = 1 , inplace = True) # For Permanent Deletion, use INPLACE = TRUE

# %%
df
# Out:
#      Name  Age      City  Salary
# 0    John   28  New York   65000
# 1    Anna   34     Paris   70000
# 2   Peter   29    Berlin   62000
# 3   Linda   42    London   85000
# 4   David   25     Tokyo   55000
# 5  Sophia   31    Sydney   78000

# %%
df.drop(['Age', 'City'], axis = 1) # for multi-col removal, use []
# Out:
#      Name  Salary
# 0    John   65000
# 1    Anna   70000
# 2   Peter   62000
# 3   Linda   85000
# 4   David   55000
# 5  Sophia   78000

# %%
df.loc[0] # Selecting Rows
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df.loc[[0,3]]
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 3  Linda   42    London   85000

# %%
df.loc[[0,1,2]][["Name","Age"]] # Specific Col of Specific Rows
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29

# %%
#Selecting People Whose Age > 30
df[df["Age"]>30]
# Out:
#      Name  Age    City  Salary
# 1    Anna   34   Paris   70000
# 3   Linda   42  London   85000
# 5  Sophia   31  Sydney   78000

# %%
#Selecting People Whose Age > 30 and City = Paris
df[(df["Age"]>30) & (df["City"] == "Paris")]  #while using multiple & or | operations, use ()
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
