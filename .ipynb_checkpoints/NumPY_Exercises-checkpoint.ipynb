# %%
import numpy as np

# %%
data = np.array([[18,72,78],[19,99,89],[17,88,71],[18,72,78],[12,78,71],[15,98,99]]) #Age, Maths marks, Sci Marks
data
print(data)
# Out:
# [[18 72 78]
#  [19 99 89]
#  [17 88 71]
#  [18 72 78]
#  [12 78 71]
#  [15 98 99]]

# %%
#get the shape of marks
data.shape
# Out:
# (6, 3)

# %%
#avg age
sum = np.sum(data, axis=0)
avg=sum[0]/6
print(avg)
# Out:
# 16.5

# %%
# OR 
np.mean(data[:,0])
# Out:
# np.float64(16.5)

# %%
#Print all Maths Marks
print(data[:,1])
# Out:
# [72 99 88 72 78 98]

# %%
#max Science marks
print(data[:,2].max())
# Out:
# 99

# %%
#Info of Student having marks greater than 90 in maths
print(data[data[:,1]>=90])
# Out:
# [[19 99 89]
#  [15 98 99]]

# %%
#Increase maths marks by 5
data[:,1] = data[:,1] +5
print(data)
# Out:
# [[ 18  73  78]
#  [ 19 100  89]
#  [ 17  89  71]
#  [ 18  73  78]
#  [ 12  79  71]
#  [ 15  99  99]]

# %%
#how many students are younger than 19
print(data[data[:,0]<19])
# Out:
# [[18 73 78]
#  [17 89 71]
#  [18 73 78]
#  [12 79 71]
#  [15 99 99]]

# %%
#Avg Marks of Both Subjects
print("AVG Maths Marks : ", data[:,1].mean() ,"AVG Science Marks : ", data[:,2].mean())
# Out:
# AVG Maths Marks :  85.5 AVG Science Marks :  81.0

# %%
#Get Data of Students who scored atleast 80 in both subjects
print(data[(data[:,1]>=80) & (data[:,2]>=80)])
# Out:
# [[ 19 100  89]
#  [ 15  99  99]]

# %%
#Replace all marks of science <75 to 0
data[:,2][data[:,2]<75]=0
data
# Out:
# array([[ 18,  73,  78],
#        [ 19, 100,  89],
#        [ 17,  89,   0],
#        [ 18,  73,  78],
#        [ 12,  79,   0],
#        [ 15,  99,  99]])
